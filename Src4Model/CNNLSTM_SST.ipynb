# %% [markdown]
# # CNN+LSTM

# %%
import os
import numpy as np
import string
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import pickle


from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
from gensim.models.keyedvectors import KeyedVectors

from tensorflow.keras.models import load_model
from tensorflow.keras.activations import relu
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (
    Input,
    Dense,
    Embedding,
    Flatten,
    Conv1D,
    MaxPooling1D,
    Add,
    Lambda,
    Dropout,
    concatenate,
    LSTM,
)
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.backend import l2_normalize
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

from sklearn.metrics import classification_report
from nltk.corpus import stopwords
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from IPython.display import SVG

# %%
import pandas as pd

train_df = pd.read_csv(
    "/content/drive/MyDrive/Sentiment Analysis/SST-2/train.csv", header=None, sep="\t", names=["label", "text"]
)
dev_df = pd.read_csv(
    "/content/drive/MyDrive/Sentiment Analysis/SST-2/dev.csv", header=None, sep="\t", names=["label", "text"]
)
test_df = pd.read_csv(
    "/content/drive/MyDrive/Sentiment Analysis/SST-2/test.csv", header=None, sep="\t", names=["label", "text"]
)


def ModiData(obj_df):
    obj_df = obj_df[obj_df["label"] != 2]
    # obj_df["label"] = obj_df["label"].astype(string)
    obj_df.label = obj_df.label.replace(0, "neg")
    obj_df.label = obj_df.label.replace(1, "neg")
    obj_df.label = obj_df.label.replace(3, "pos")
    obj_df.label = obj_df.label.replace(4, "pos")
    obj_df = obj_df.fillna(0)
    # obj_df["label"] = obj_df["label"].astype(int)
    return obj_df


def clean_line(line):
    # split into tokens by white space
    tokens = line.split()
    # remove punctuation from each token
    table = str.maketrans("", "", string.punctuation)
    tokens = [w.translate(table) for w in tokens]
    # remove remaining tokens that are not alphabetic
    tokens = [word for word in tokens if word.isalpha()]
    # filter out stop words
    stop_words = set(stopwords.words("english"))
    tokens = [w for w in tokens if not w in stop_words]
    # filter out short tokens
    tokens = [word for word in tokens if len(word) > 1]
    return tokens


def create_tokenizer(lines):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(lines)
    return tokenizer


def encode_text(tokenizer, lines, length):
    # integer encode
    encoded = tokenizer.texts_to_sequences(lines)
    # pad encoded sequences
    padded = pad_sequences(encoded, maxlen=length, padding="post")
    return padded

# %%
train_df = ModiData(train_df)
dev_df = ModiData(dev_df)
test_df = ModiData(test_df)

train_x = train_df.text.tolist()
train_y = train_df.label
dev_x = dev_df.text.tolist()
dev_y = dev_df.label
test_x = test_df.text.tolist()
test_y = test_df.label

max_len = 49
# tokenizer = create_tokenizer(train_x)
with open("/content/drive/MyDrive/Sentiment Analysis/tokenizer/49in_SST.pickle", "rb") as handle:
    tokenizer = pickle.load(handle)
# calculate vocabulary size
vocab_size = len(tokenizer.word_index) + 1
word_index = tokenizer.word_index
train_x = encode_text(tokenizer, train_x, max_len)
dev_x = encode_text(tokenizer, dev_x, max_len)
test_x = encode_text(tokenizer, test_x, max_len)

le = LabelEncoder()
train_y = le.fit_transform(train_y).reshape(-1, 1)
dev_y = le.transform(dev_y).reshape(-1, 1)
test_y = le.transform(test_y).reshape(-1, 1)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:5170: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %% [markdown]
# ## Model

# %%
def get_embeddings_layer(name, max_len, trainable):
    embedding_layer = Embedding(
        input_dim=len(word_index)+1,
        output_dim=50,
        input_length=max_len,
        # weights=[embeddings_matrix],
        trainable=trainable,
        name=name,
    )
    return embedding_layer


def get_conv_pool(x_input, max_len, sufix, n_grams=[3, 4, 5], feature_maps=100):
    branches = []
    for n in n_grams:
        branch = Conv1D(
            filters=feature_maps,
            kernel_size=n,
            activation=relu,
            name="Conv_" + sufix + "_" + str(n),
        )(x_input)
        branch = MaxPooling1D(
            pool_size=2,
            strides=None,
            padding="valid",
            name="MaxPooling_" + sufix + "_" + str(n),
        )(branch)
        # branch = Flatten(name="Flatten_" + sufix + "_" + str(n))(branch)
        branches.append(branch)
    return branches


def get_cnn_rand(max_len):
    embeddings_layer_channel_1 = get_embeddings_layer(
        "embeddings_layer_dynamic", max_len, trainable=True
    )

    input_dynamic = Input(shape=(max_len,), dtype="int32", name="input_dynamic")
    x = embeddings_layer_channel_1(input_dynamic)
    branches_dynamic = get_conv_pool(x, max_len, "dynamic")
    z_dynamic = concatenate(branches_dynamic, axis=1)

    layer = LSTM(64,return_sequences=True)(z_dynamic)
    layer = LSTM(64)(layer)

    z = Dropout(0.1)(layer)
    z = layer = Dense(20, activation="relu", name="FC1")(z)
    # z = Dropout(0.1)(z)
    o = Dense(1, activation="sigmoid", name="output")(z)

    model = Model(inputs=input_dynamic, outputs=o)
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["acc"])

    return model

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get("val_loss") <0.49:
            print("\nReached 0.49 loss!")
            self.model.stop_training = True


beststop = myCallback()
earlystop = EarlyStopping(monitor="val_loss", min_delta=0.0001)
checkpointer = ModelCheckpoint(filepath="./weights.hdf5", verbose=1)

# %%
def TrainModel(num):
    while num > 0:
        model = get_cnn_rand(max_len)
        # model.summary()
        history = model.fit(
            x=train_x,
            y=train_y,
            batch_size=400,
            epochs=20,
            validation_data=(test_x, test_y),
            callbacks=[beststop, earlystop],
        )
        if history.history["val_acc"][-1] > 0.805:
            save_name = (
                "/content/drive/MyDrive/Sentiment Analysis/Model/CNNLSTM_SST/"
                + str(history.history["val_loss"][-1])[2:6]
                + "_"
                + str(history.history["val_acc"][-1])[2:6]
                + ".hdf5"
            )
            num -= 1
            model.save(save_name)

# %%
TrainModel(10)
# Out:
# Epoch 1/20
# 18/18 [==============================] - 20s 93ms/step - loss: 0.6925 - acc: 0.5215 - val_loss: 0.6939 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6897 - acc: 0.5261 - val_loss: 0.6482 - val_acc: 0.6452
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.5529 - acc: 0.7291 - val_loss: 0.4752 - val_acc: 0.7924
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 70ms/step - loss: 0.6930 - acc: 0.4974 - val_loss: 0.6941 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.6917 - acc: 0.5257 - val_loss: 0.6930 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6746 - acc: 0.5661 - val_loss: 0.5522 - val_acc: 0.7441
# Epoch 4/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.3687 - acc: 0.8449 - val_loss: 0.4844 - val_acc: 0.7836
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6924 - acc: 0.5200 - val_loss: 0.6936 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6895 - acc: 0.5174 - val_loss: 0.6414 - val_acc: 0.6815
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.5392 - acc: 0.7570 - val_loss: 0.4929 - val_acc: 0.7814
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.2515 - acc: 0.9060 - val_loss: 0.6179 - val_acc: 0.7765
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6929 - acc: 0.5154 - val_loss: 0.6940 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6918 - acc: 0.5224 - val_loss: 0.6901 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6424 - acc: 0.5922 - val_loss: 0.5191 - val_acc: 0.7611
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3280 - acc: 0.8728 - val_loss: 0.4901 - val_acc: 0.7886
# Epoch 5/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.1676 - acc: 0.9398 - val_loss: 0.6453 - val_acc: 0.8007
# Epoch 1/20
# 18/18 [==============================] - 4s 78ms/step - loss: 0.6932 - acc: 0.4924 - val_loss: 0.6951 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6925 - acc: 0.5180 - val_loss: 0.6934 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6850 - acc: 0.5289 - val_loss: 0.5945 - val_acc: 0.6936
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.4541 - acc: 0.7964 - val_loss: 0.4620 - val_acc: 0.7963
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 69ms/step - loss: 0.6931 - acc: 0.5219 - val_loss: 0.6935 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6917 - acc: 0.5227 - val_loss: 0.6882 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6323 - acc: 0.6281 - val_loss: 0.5163 - val_acc: 0.7485
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.3285 - acc: 0.8654 - val_loss: 0.4634 - val_acc: 0.7985
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 69ms/step - loss: 0.6928 - acc: 0.5110 - val_loss: 0.6930 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6909 - acc: 0.5262 - val_loss: 0.6776 - val_acc: 0.6584
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.5936 - acc: 0.7135 - val_loss: 0.4846 - val_acc: 0.7897
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6926 - acc: 0.5186 - val_loss: 0.6933 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6895 - acc: 0.5215 - val_loss: 0.6292 - val_acc: 0.6870
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.5688 - acc: 0.7353 - val_loss: 0.4881 - val_acc: 0.7776
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 72ms/step - loss: 0.6930 - acc: 0.5062 - val_loss: 0.6945 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6914 - acc: 0.5203 - val_loss: 0.6804 - val_acc: 0.5019
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6174 - acc: 0.6392 - val_loss: 0.5102 - val_acc: 0.7556
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3180 - acc: 0.8722 - val_loss: 0.4858 - val_acc: 0.7935
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 90ms/step - loss: 0.6929 - acc: 0.5105 - val_loss: 0.6940 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6911 - acc: 0.5198 - val_loss: 0.6720 - val_acc: 0.6085
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.5963 - acc: 0.7061 - val_loss: 0.4823 - val_acc: 0.7732
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6930 - acc: 0.5240 - val_loss: 0.6967 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6944 - acc: 0.5078 - val_loss: 0.6919 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6680 - acc: 0.5442 - val_loss: 0.5505 - val_acc: 0.7408
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.3698 - acc: 0.8495 - val_loss: 0.4582 - val_acc: 0.8007
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6928 - acc: 0.5192 - val_loss: 0.6939 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6915 - acc: 0.5226 - val_loss: 0.6807 - val_acc: 0.6425
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6191 - acc: 0.6691 - val_loss: 0.5208 - val_acc: 0.7430
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.3072 - acc: 0.8727 - val_loss: 0.4866 - val_acc: 0.7924
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 69ms/step - loss: 0.6927 - acc: 0.5256 - val_loss: 0.6938 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6920 - acc: 0.5195 - val_loss: 0.6918 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6668 - acc: 0.5216 - val_loss: 0.6141 - val_acc: 0.7172
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.5119 - acc: 0.7548 - val_loss: 0.5584 - val_acc: 0.7661
# Epoch 5/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.2779 - acc: 0.8998 - val_loss: 0.5560 - val_acc: 0.7864
# Epoch 6/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.1671 - acc: 0.9419 - val_loss: 0.6534 - val_acc: 0.7908
# Epoch 1/20
# 18/18 [==============================] - 4s 70ms/step - loss: 0.6926 - acc: 0.5227 - val_loss: 0.6936 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6900 - acc: 0.5234 - val_loss: 0.6530 - val_acc: 0.6606
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.5581 - acc: 0.7538 - val_loss: 0.4727 - val_acc: 0.7924
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 72ms/step - loss: 0.6925 - acc: 0.5285 - val_loss: 0.6931 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6924 - acc: 0.5241 - val_loss: 0.6923 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6674 - acc: 0.5606 - val_loss: 0.5401 - val_acc: 0.7392
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.3600 - acc: 0.8506 - val_loss: 0.4657 - val_acc: 0.8023
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 74ms/step - loss: 0.6928 - acc: 0.5170 - val_loss: 0.6951 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6912 - acc: 0.5225 - val_loss: 0.6885 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6337 - acc: 0.6140 - val_loss: 0.5217 - val_acc: 0.7644
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3487 - acc: 0.8642 - val_loss: 0.4689 - val_acc: 0.7880
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6919 - acc: 0.5252 - val_loss: 0.6928 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6884 - acc: 0.5326 - val_loss: 0.6352 - val_acc: 0.6941
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.5108 - acc: 0.7823 - val_loss: 0.4665 - val_acc: 0.7913
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 70ms/step - loss: 0.6927 - acc: 0.5298 - val_loss: 0.6934 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6918 - acc: 0.5258 - val_loss: 0.6925 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6752 - acc: 0.5497 - val_loss: 0.6275 - val_acc: 0.6216
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.4866 - acc: 0.7720 - val_loss: 0.4892 - val_acc: 0.7869
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 69ms/step - loss: 0.6928 - acc: 0.5099 - val_loss: 0.6941 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6918 - acc: 0.5230 - val_loss: 0.6918 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.6591 - acc: 0.5831 - val_loss: 0.6260 - val_acc: 0.6793
# Epoch 4/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.4276 - acc: 0.8078 - val_loss: 0.4933 - val_acc: 0.7974
# Epoch 5/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.1862 - acc: 0.9296 - val_loss: 0.5591 - val_acc: 0.7886
# Epoch 1/20
# 18/18 [==============================] - 4s 68ms/step - loss: 0.6928 - acc: 0.5089 - val_loss: 0.6935 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6912 - acc: 0.5171 - val_loss: 0.6723 - val_acc: 0.5892
# Epoch 3/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.5961 - acc: 0.6864 - val_loss: 0.5360 - val_acc: 0.7479
# Epoch 4/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.2962 - acc: 0.8801 - val_loss: 0.5016 - val_acc: 0.7968
# Epoch 5/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.1370 - acc: 0.9567 - val_loss: 0.6730 - val_acc: 0.7908
# Epoch 1/20
# 18/18 [==============================] - 4s 69ms/step - loss: 0.6932 - acc: 0.5079 - val_loss: 0.6942 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.6924 - acc: 0.5185 - val_loss: 0.6938 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.6771 - acc: 0.5435 - val_loss: 0.6005 - val_acc: 0.7210
# Epoch 4/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.4128 - acc: 0.8261 - val_loss: 0.4645 - val_acc: 0.7908
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 69ms/step - loss: 0.6931 - acc: 0.5033 - val_loss: 0.6959 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6939 - acc: 0.5128 - val_loss: 0.6940 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6893 - acc: 0.5112 - val_loss: 0.6262 - val_acc: 0.6546
# Epoch 4/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.5131 - acc: 0.7722 - val_loss: 0.4757 - val_acc: 0.7886
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 69ms/step - loss: 0.6932 - acc: 0.5016 - val_loss: 0.6949 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6917 - acc: 0.5242 - val_loss: 0.6905 - val_acc: 0.5014
# Epoch 3/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.6514 - acc: 0.5903 - val_loss: 0.5072 - val_acc: 0.7589
# Epoch 4/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.3225 - acc: 0.8712 - val_loss: 0.5276 - val_acc: 0.7765
# Epoch 1/20
# 18/18 [==============================] - 4s 70ms/step - loss: 0.6927 - acc: 0.5237 - val_loss: 0.6945 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.6916 - acc: 0.5247 - val_loss: 0.6893 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6546 - acc: 0.5898 - val_loss: 0.5497 - val_acc: 0.7518
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.3508 - acc: 0.8617 - val_loss: 0.4816 - val_acc: 0.7985
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 68ms/step - loss: 0.6927 - acc: 0.5150 - val_loss: 0.6933 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.6923 - acc: 0.5165 - val_loss: 0.6913 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.6534 - acc: 0.5892 - val_loss: 0.5611 - val_acc: 0.7166
# Epoch 4/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.3370 - acc: 0.8661 - val_loss: 0.6377 - val_acc: 0.7177
# Epoch 1/20
# 18/18 [==============================] - 4s 70ms/step - loss: 0.6931 - acc: 0.5149 - val_loss: 0.7025 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6925 - acc: 0.5266 - val_loss: 0.6921 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6740 - acc: 0.5443 - val_loss: 0.5647 - val_acc: 0.7397
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.4268 - acc: 0.8266 - val_loss: 0.4531 - val_acc: 0.8012
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 70ms/step - loss: 0.6930 - acc: 0.5147 - val_loss: 0.6933 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.6915 - acc: 0.5103 - val_loss: 0.6797 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6265 - acc: 0.6425 - val_loss: 0.5355 - val_acc: 0.7271
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.3636 - acc: 0.8477 - val_loss: 0.5013 - val_acc: 0.8023
# Epoch 5/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.1666 - acc: 0.9427 - val_loss: 0.5450 - val_acc: 0.8056
# Epoch 1/20
# 18/18 [==============================] - 4s 69ms/step - loss: 0.6927 - acc: 0.5170 - val_loss: 0.6935 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6918 - acc: 0.5270 - val_loss: 0.6920 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6739 - acc: 0.5499 - val_loss: 0.5234 - val_acc: 0.7490
# Epoch 4/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.3596 - acc: 0.8438 - val_loss: 0.5132 - val_acc: 0.7864
# Epoch 5/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.1661 - acc: 0.9437 - val_loss: 0.5369 - val_acc: 0.8056
# Epoch 1/20
# 18/18 [==============================] - 4s 69ms/step - loss: 0.6935 - acc: 0.5002 - val_loss: 0.6953 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6900 - acc: 0.5272 - val_loss: 0.6621 - val_acc: 0.5305
# Epoch 3/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.5746 - acc: 0.6814 - val_loss: 0.5192 - val_acc: 0.7348
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.2809 - acc: 0.8864 - val_loss: 0.5138 - val_acc: 0.7869
# Epoch 5/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.1328 - acc: 0.9596 - val_loss: 0.8352 - val_acc: 0.7705
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6926 - acc: 0.5167 - val_loss: 0.6935 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6918 - acc: 0.5215 - val_loss: 0.6862 - val_acc: 0.5014
# Epoch 3/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.6499 - acc: 0.6199 - val_loss: 0.5292 - val_acc: 0.7364
# Epoch 4/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.3538 - acc: 0.8522 - val_loss: 0.5286 - val_acc: 0.7803
# Epoch 5/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.1512 - acc: 0.9517 - val_loss: 0.5319 - val_acc: 0.7963
# Epoch 1/20
# 18/18 [==============================] - 4s 69ms/step - loss: 0.6928 - acc: 0.5055 - val_loss: 0.6934 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.6919 - acc: 0.5184 - val_loss: 0.6847 - val_acc: 0.5063
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6231 - acc: 0.6494 - val_loss: 0.4992 - val_acc: 0.7573
# Epoch 4/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.3012 - acc: 0.8774 - val_loss: 0.4909 - val_acc: 0.7902
# Epoch 5/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.1407 - acc: 0.9523 - val_loss: 0.5515 - val_acc: 0.7924
# Epoch 1/20
# 18/18 [==============================] - 4s 72ms/step - loss: 0.6926 - acc: 0.5275 - val_loss: 0.6935 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.6922 - acc: 0.5179 - val_loss: 0.6919 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6453 - acc: 0.6024 - val_loss: 0.5307 - val_acc: 0.7155
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.3417 - acc: 0.8527 - val_loss: 0.5035 - val_acc: 0.8012
# Epoch 5/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.1541 - acc: 0.9472 - val_loss: 0.6203 - val_acc: 0.7941
# Epoch 1/20
# 18/18 [==============================] - 4s 86ms/step - loss: 0.6928 - acc: 0.5199 - val_loss: 0.6933 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6925 - acc: 0.5196 - val_loss: 0.6948 - val_acc: 0.4992
# Epoch 1/20
# 18/18 [==============================] - 4s 69ms/step - loss: 0.6923 - acc: 0.5255 - val_loss: 0.6933 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.6923 - acc: 0.5095 - val_loss: 0.6905 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.6491 - acc: 0.5815 - val_loss: 0.5346 - val_acc: 0.7573
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.3577 - acc: 0.8563 - val_loss: 0.4790 - val_acc: 0.8012
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 70ms/step - loss: 0.6925 - acc: 0.5175 - val_loss: 0.6932 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6925 - acc: 0.5163 - val_loss: 0.6939 - val_acc: 0.4992
# Epoch 1/20
# 18/18 [==============================] - 4s 70ms/step - loss: 0.6922 - acc: 0.5185 - val_loss: 0.6932 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6921 - acc: 0.5181 - val_loss: 0.6871 - val_acc: 0.5003
# Epoch 3/20
# 18/18 [==============================] - 1s 30ms/step - loss: 0.6484 - acc: 0.5929 - val_loss: 0.5727 - val_acc: 0.7441
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.3974 - acc: 0.8558 - val_loss: 0.4711 - val_acc: 0.7908
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 70ms/step - loss: 0.6926 - acc: 0.5119 - val_loss: 0.6934 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6929 - acc: 0.5175 - val_loss: 0.6937 - val_acc: 0.4992
# Epoch 1/20
# 18/18 [==============================] - 4s 70ms/step - loss: 0.6927 - acc: 0.5192 - val_loss: 0.6955 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6905 - acc: 0.5271 - val_loss: 0.6728 - val_acc: 0.5986
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6164 - acc: 0.6632 - val_loss: 0.5203 - val_acc: 0.7529
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.3453 - acc: 0.8559 - val_loss: 0.4928 - val_acc: 0.7847
# Epoch 5/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.1698 - acc: 0.9497 - val_loss: 0.6849 - val_acc: 0.7941
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6927 - acc: 0.5049 - val_loss: 0.6930 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6908 - acc: 0.5278 - val_loss: 0.6668 - val_acc: 0.5805
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.5616 - acc: 0.7112 - val_loss: 0.4921 - val_acc: 0.7727
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.2611 - acc: 0.8881 - val_loss: 0.4980 - val_acc: 0.7935
# Epoch 1/20
# 18/18 [==============================] - 4s 74ms/step - loss: 0.6927 - acc: 0.5188 - val_loss: 0.6932 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6909 - acc: 0.5172 - val_loss: 0.6647 - val_acc: 0.6612
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.5799 - acc: 0.7263 - val_loss: 0.5134 - val_acc: 0.7677
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3139 - acc: 0.8826 - val_loss: 0.5361 - val_acc: 0.8051
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6926 - acc: 0.5167 - val_loss: 0.6934 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6905 - acc: 0.5280 - val_loss: 0.6673 - val_acc: 0.5519
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.5825 - acc: 0.7066 - val_loss: 0.5290 - val_acc: 0.7518
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.2873 - acc: 0.8929 - val_loss: 0.4747 - val_acc: 0.8023
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 73ms/step - loss: 0.6925 - acc: 0.5312 - val_loss: 0.6932 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6923 - acc: 0.5116 - val_loss: 0.6827 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6189 - acc: 0.6227 - val_loss: 0.5165 - val_acc: 0.7661
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3286 - acc: 0.8742 - val_loss: 0.4893 - val_acc: 0.7946
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 72ms/step - loss: 0.6919 - acc: 0.5288 - val_loss: 0.6930 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6923 - acc: 0.5211 - val_loss: 0.6893 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6569 - acc: 0.5895 - val_loss: 0.5335 - val_acc: 0.7414
# Epoch 4/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.3742 - acc: 0.8434 - val_loss: 0.5026 - val_acc: 0.7908
# Epoch 5/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.1833 - acc: 0.9334 - val_loss: 0.5599 - val_acc: 0.7996
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6930 - acc: 0.5115 - val_loss: 0.6953 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6912 - acc: 0.5200 - val_loss: 0.6724 - val_acc: 0.5189
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.5865 - acc: 0.6873 - val_loss: 0.5048 - val_acc: 0.7628
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.2708 - acc: 0.8959 - val_loss: 0.5183 - val_acc: 0.7781
# Epoch 1/20
# 18/18 [==============================] - 4s 70ms/step - loss: 0.6928 - acc: 0.5193 - val_loss: 0.6944 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6910 - acc: 0.5255 - val_loss: 0.6700 - val_acc: 0.6134
# Epoch 3/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.5947 - acc: 0.6803 - val_loss: 0.5734 - val_acc: 0.7512
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.2877 - acc: 0.8882 - val_loss: 0.4974 - val_acc: 0.7930
# Epoch 5/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.1231 - acc: 0.9618 - val_loss: 0.6435 - val_acc: 0.7875
# Epoch 1/20
# 18/18 [==============================] - 4s 72ms/step - loss: 0.6926 - acc: 0.5197 - val_loss: 0.6947 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6914 - acc: 0.5203 - val_loss: 0.6799 - val_acc: 0.4997
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6069 - acc: 0.6554 - val_loss: 0.5092 - val_acc: 0.7507
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.3151 - acc: 0.8716 - val_loss: 0.4918 - val_acc: 0.7990
# Epoch 5/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.1600 - acc: 0.9476 - val_loss: 0.6836 - val_acc: 0.7864
# Epoch 1/20
# 18/18 [==============================] - 4s 87ms/step - loss: 0.6928 - acc: 0.5124 - val_loss: 0.6941 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6917 - acc: 0.5232 - val_loss: 0.6884 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6330 - acc: 0.6069 - val_loss: 0.5062 - val_acc: 0.7617
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.3151 - acc: 0.8745 - val_loss: 0.4932 - val_acc: 0.7935
# Epoch 5/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.1518 - acc: 0.9490 - val_loss: 0.5306 - val_acc: 0.8018
# Epoch 1/20
# 18/18 [==============================] - 4s 69ms/step - loss: 0.6929 - acc: 0.5080 - val_loss: 0.6952 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6913 - acc: 0.5281 - val_loss: 0.6906 - val_acc: 0.5964
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6586 - acc: 0.5959 - val_loss: 0.5989 - val_acc: 0.6991
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3655 - acc: 0.8346 - val_loss: 0.5187 - val_acc: 0.7595
# Epoch 5/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.1700 - acc: 0.9392 - val_loss: 0.6397 - val_acc: 0.7935
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6922 - acc: 0.5323 - val_loss: 0.6931 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6911 - acc: 0.5280 - val_loss: 0.6756 - val_acc: 0.6321
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6089 - acc: 0.6987 - val_loss: 0.6193 - val_acc: 0.6321
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3862 - acc: 0.8228 - val_loss: 0.6691 - val_acc: 0.7392
# Epoch 1/20
# 18/18 [==============================] - 4s 70ms/step - loss: 0.6929 - acc: 0.5039 - val_loss: 0.6941 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6923 - acc: 0.5222 - val_loss: 0.6929 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6806 - acc: 0.5662 - val_loss: 0.7415 - val_acc: 0.6046
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6921 - acc: 0.5270 - val_loss: 0.6930 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6923 - acc: 0.5188 - val_loss: 0.6901 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6432 - acc: 0.5851 - val_loss: 0.5404 - val_acc: 0.7809
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3189 - acc: 0.8734 - val_loss: 0.4980 - val_acc: 0.7957
# Epoch 5/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.1627 - acc: 0.9465 - val_loss: 0.6763 - val_acc: 0.7792
# Epoch 1/20
# 18/18 [==============================] - 4s 72ms/step - loss: 0.6924 - acc: 0.5238 - val_loss: 0.6933 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6914 - acc: 0.5356 - val_loss: 0.6901 - val_acc: 0.5876
# Epoch 3/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6640 - acc: 0.6034 - val_loss: 0.6182 - val_acc: 0.7013
# Epoch 4/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.3506 - acc: 0.8477 - val_loss: 0.4886 - val_acc: 0.7924
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 70ms/step - loss: 0.6929 - acc: 0.5288 - val_loss: 0.6936 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6921 - acc: 0.5181 - val_loss: 0.6889 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6361 - acc: 0.5842 - val_loss: 0.5109 - val_acc: 0.7770
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3169 - acc: 0.8812 - val_loss: 0.5198 - val_acc: 0.7743
# Epoch 1/20
# 18/18 [==============================] - 4s 74ms/step - loss: 0.6929 - acc: 0.5148 - val_loss: 0.6940 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6911 - acc: 0.5250 - val_loss: 0.6821 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6285 - acc: 0.6295 - val_loss: 0.5159 - val_acc: 0.7688
# Epoch 4/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.2982 - acc: 0.8831 - val_loss: 0.4933 - val_acc: 0.7957
# Epoch 5/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.1408 - acc: 0.9528 - val_loss: 0.5647 - val_acc: 0.8051
# Epoch 1/20
# 18/18 [==============================] - 4s 70ms/step - loss: 0.6927 - acc: 0.5189 - val_loss: 0.6949 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6901 - acc: 0.5253 - val_loss: 0.6773 - val_acc: 0.5618
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6066 - acc: 0.6594 - val_loss: 0.4958 - val_acc: 0.7650
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.2953 - acc: 0.8869 - val_loss: 0.5226 - val_acc: 0.7556
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6927 - acc: 0.5079 - val_loss: 0.6941 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6921 - acc: 0.5199 - val_loss: 0.6921 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6538 - acc: 0.5816 - val_loss: 0.5008 - val_acc: 0.7551
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3091 - acc: 0.8778 - val_loss: 0.4934 - val_acc: 0.7968
# Epoch 5/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.1357 - acc: 0.9532 - val_loss: 0.5959 - val_acc: 0.7985
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6929 - acc: 0.5111 - val_loss: 0.6978 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6909 - acc: 0.5199 - val_loss: 0.6511 - val_acc: 0.6474
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.5583 - acc: 0.7406 - val_loss: 0.5267 - val_acc: 0.7496
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.2748 - acc: 0.8964 - val_loss: 0.5224 - val_acc: 0.7930
# Epoch 5/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.1131 - acc: 0.9624 - val_loss: 0.5574 - val_acc: 0.7974
# Epoch 1/20
# 18/18 [==============================] - 4s 89ms/step - loss: 0.6927 - acc: 0.5140 - val_loss: 0.6941 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6921 - acc: 0.5150 - val_loss: 0.6887 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6238 - acc: 0.6361 - val_loss: 0.5540 - val_acc: 0.7199
# Epoch 4/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.3282 - acc: 0.8644 - val_loss: 0.4939 - val_acc: 0.7957
# Epoch 5/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.1512 - acc: 0.9491 - val_loss: 0.5756 - val_acc: 0.7963
# Epoch 1/20
# 18/18 [==============================] - 4s 73ms/step - loss: 0.6926 - acc: 0.5220 - val_loss: 0.6933 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6916 - acc: 0.5228 - val_loss: 0.6817 - val_acc: 0.5200
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6233 - acc: 0.6450 - val_loss: 0.5005 - val_acc: 0.7666
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3313 - acc: 0.8649 - val_loss: 0.4862 - val_acc: 0.7957
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 73ms/step - loss: 0.6924 - acc: 0.5214 - val_loss: 0.6934 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6918 - acc: 0.5247 - val_loss: 0.6911 - val_acc: 0.4997
# Epoch 3/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6594 - acc: 0.5775 - val_loss: 0.5229 - val_acc: 0.7518
# Epoch 4/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.3780 - acc: 0.8495 - val_loss: 0.5775 - val_acc: 0.7540
# Epoch 1/20
# 18/18 [==============================] - 4s 73ms/step - loss: 0.6924 - acc: 0.5270 - val_loss: 0.6933 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6921 - acc: 0.5236 - val_loss: 0.6922 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6617 - acc: 0.5499 - val_loss: 0.5412 - val_acc: 0.7035
# Epoch 4/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.3949 - acc: 0.8199 - val_loss: 0.5053 - val_acc: 0.7996
# Epoch 5/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.1769 - acc: 0.9386 - val_loss: 0.5822 - val_acc: 0.8001
# Epoch 1/20
# 18/18 [==============================] - 4s 70ms/step - loss: 0.6925 - acc: 0.5123 - val_loss: 0.6931 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6917 - acc: 0.5202 - val_loss: 0.6785 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6183 - acc: 0.6430 - val_loss: 0.5144 - val_acc: 0.7457
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3450 - acc: 0.8556 - val_loss: 0.5081 - val_acc: 0.7886
# Epoch 5/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.1581 - acc: 0.9493 - val_loss: 0.6481 - val_acc: 0.7913
# Epoch 1/20
# 18/18 [==============================] - 4s 72ms/step - loss: 0.6925 - acc: 0.5229 - val_loss: 0.6930 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6909 - acc: 0.5291 - val_loss: 0.6743 - val_acc: 0.5107
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6186 - acc: 0.6402 - val_loss: 0.5381 - val_acc: 0.7194
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3414 - acc: 0.8467 - val_loss: 0.4664 - val_acc: 0.8007
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6925 - acc: 0.5290 - val_loss: 0.6933 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6909 - acc: 0.5254 - val_loss: 0.6733 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6103 - acc: 0.6034 - val_loss: 0.5495 - val_acc: 0.7304
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3337 - acc: 0.8663 - val_loss: 0.4769 - val_acc: 0.7957
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 72ms/step - loss: 0.6932 - acc: 0.5264 - val_loss: 0.6931 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6928 - acc: 0.5106 - val_loss: 0.6941 - val_acc: 0.4992
# Epoch 1/20
# 18/18 [==============================] - 4s 72ms/step - loss: 0.6925 - acc: 0.5241 - val_loss: 0.6935 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6904 - acc: 0.5350 - val_loss: 0.6810 - val_acc: 0.6694
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6098 - acc: 0.6968 - val_loss: 0.5137 - val_acc: 0.7496
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.2871 - acc: 0.8885 - val_loss: 0.4886 - val_acc: 0.8045
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 69ms/step - loss: 0.6926 - acc: 0.5175 - val_loss: 0.6932 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6924 - acc: 0.5185 - val_loss: 0.6929 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6701 - acc: 0.5590 - val_loss: 0.5692 - val_acc: 0.6892
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.3841 - acc: 0.8368 - val_loss: 0.4837 - val_acc: 0.7705
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6928 - acc: 0.5186 - val_loss: 0.6954 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6891 - acc: 0.5276 - val_loss: 0.6381 - val_acc: 0.7062
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.5344 - acc: 0.7709 - val_loss: 0.4789 - val_acc: 0.7886
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 72ms/step - loss: 0.6927 - acc: 0.5081 - val_loss: 0.6936 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6914 - acc: 0.5257 - val_loss: 0.6833 - val_acc: 0.5036
# Epoch 3/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6150 - acc: 0.6499 - val_loss: 0.5490 - val_acc: 0.7150
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3578 - acc: 0.8541 - val_loss: 0.5319 - val_acc: 0.7880
# Epoch 5/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.1499 - acc: 0.9504 - val_loss: 0.7967 - val_acc: 0.7633
# Epoch 1/20
# 18/18 [==============================] - 4s 70ms/step - loss: 0.6930 - acc: 0.5113 - val_loss: 0.6931 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6927 - acc: 0.5123 - val_loss: 0.6926 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6691 - acc: 0.5475 - val_loss: 0.5526 - val_acc: 0.7046
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3903 - acc: 0.8243 - val_loss: 0.4825 - val_acc: 0.7952
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6929 - acc: 0.5156 - val_loss: 0.6946 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6913 - acc: 0.5249 - val_loss: 0.6855 - val_acc: 0.5014
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6172 - acc: 0.6353 - val_loss: 0.5015 - val_acc: 0.7639
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.2807 - acc: 0.8906 - val_loss: 0.5193 - val_acc: 0.7781
# Epoch 1/20
# 18/18 [==============================] - 4s 73ms/step - loss: 0.6930 - acc: 0.5209 - val_loss: 0.6942 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6907 - acc: 0.5320 - val_loss: 0.6872 - val_acc: 0.5755
# Epoch 3/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6373 - acc: 0.6308 - val_loss: 0.5293 - val_acc: 0.7529
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3056 - acc: 0.8737 - val_loss: 0.4837 - val_acc: 0.7814
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 70ms/step - loss: 0.6926 - acc: 0.5083 - val_loss: 0.6931 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6922 - acc: 0.5330 - val_loss: 0.6921 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6695 - acc: 0.5604 - val_loss: 0.6253 - val_acc: 0.6145
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.4599 - acc: 0.7819 - val_loss: 0.4877 - val_acc: 0.7716
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6928 - acc: 0.5171 - val_loss: 0.6946 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6924 - acc: 0.5132 - val_loss: 0.6863 - val_acc: 0.4997
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6295 - acc: 0.6408 - val_loss: 0.5732 - val_acc: 0.7199
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3090 - acc: 0.8717 - val_loss: 0.4685 - val_acc: 0.8012
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 90ms/step - loss: 0.6930 - acc: 0.5175 - val_loss: 0.6941 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.6920 - acc: 0.5181 - val_loss: 0.6925 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6507 - acc: 0.5800 - val_loss: 0.5755 - val_acc: 0.6864
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3671 - acc: 0.8347 - val_loss: 0.5299 - val_acc: 0.7869
# Epoch 5/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.1578 - acc: 0.9416 - val_loss: 0.6119 - val_acc: 0.7803
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6927 - acc: 0.5161 - val_loss: 0.6933 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6920 - acc: 0.5263 - val_loss: 0.6932 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6703 - acc: 0.5529 - val_loss: 0.5371 - val_acc: 0.7177
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.3892 - acc: 0.8356 - val_loss: 0.5122 - val_acc: 0.7688
# Epoch 5/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.1963 - acc: 0.9217 - val_loss: 0.6458 - val_acc: 0.7803
# Epoch 1/20
# 18/18 [==============================] - 4s 72ms/step - loss: 0.6924 - acc: 0.5213 - val_loss: 0.6931 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6830 - acc: 0.5359 - val_loss: 0.6517 - val_acc: 0.6485
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.5462 - acc: 0.7510 - val_loss: 0.6139 - val_acc: 0.7424
# Epoch 4/20
# 18/18 [==============================] - 1s 31ms/step - loss: 0.2772 - acc: 0.8944 - val_loss: 0.4991 - val_acc: 0.7957
# Epoch 5/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.1269 - acc: 0.9550 - val_loss: 0.7107 - val_acc: 0.7924
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6927 - acc: 0.5263 - val_loss: 0.6934 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6913 - acc: 0.5203 - val_loss: 0.6707 - val_acc: 0.5969
# Epoch 3/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.5967 - acc: 0.7114 - val_loss: 0.4714 - val_acc: 0.7935
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6923 - acc: 0.5179 - val_loss: 0.6931 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6922 - acc: 0.5193 - val_loss: 0.6873 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6412 - acc: 0.6148 - val_loss: 0.5856 - val_acc: 0.6716
# Epoch 4/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.4069 - acc: 0.8124 - val_loss: 0.5219 - val_acc: 0.7754
# Epoch 5/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.1989 - acc: 0.9280 - val_loss: 0.5705 - val_acc: 0.7858
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6924 - acc: 0.5248 - val_loss: 0.6930 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6862 - acc: 0.5258 - val_loss: 0.6396 - val_acc: 0.6546
# Epoch 3/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.5594 - acc: 0.7176 - val_loss: 0.4851 - val_acc: 0.7721
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 72ms/step - loss: 0.6927 - acc: 0.5210 - val_loss: 0.6935 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.6908 - acc: 0.5246 - val_loss: 0.6611 - val_acc: 0.6074
# Epoch 3/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.5815 - acc: 0.6950 - val_loss: 0.5345 - val_acc: 0.7595
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.3023 - acc: 0.8821 - val_loss: 0.4723 - val_acc: 0.8023
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 74ms/step - loss: 0.6923 - acc: 0.5231 - val_loss: 0.6930 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6917 - acc: 0.5216 - val_loss: 0.6776 - val_acc: 0.5135
# Epoch 3/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6042 - acc: 0.6538 - val_loss: 0.5054 - val_acc: 0.7694
# Epoch 4/20
# 18/18 [==============================] - 1s 32ms/step - loss: 0.2887 - acc: 0.8890 - val_loss: 0.5436 - val_acc: 0.7650
# Epoch 1/20
# 18/18 [==============================] - 4s 74ms/step - loss: 0.6928 - acc: 0.5084 - val_loss: 0.6950 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6901 - acc: 0.5316 - val_loss: 0.6590 - val_acc: 0.6452
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.5746 - acc: 0.7119 - val_loss: 0.5034 - val_acc: 0.7622
# Epoch 4/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.3032 - acc: 0.8963 - val_loss: 0.5399 - val_acc: 0.8094
# Epoch 1/20
# 18/18 [==============================] - 4s 74ms/step - loss: 0.6926 - acc: 0.5205 - val_loss: 0.6944 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6884 - acc: 0.5271 - val_loss: 0.6310 - val_acc: 0.6958
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.5081 - acc: 0.7829 - val_loss: 0.4944 - val_acc: 0.7716
# Epoch 4/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2371 - acc: 0.9100 - val_loss: 0.5581 - val_acc: 0.7930
# Epoch 1/20
# 18/18 [==============================] - 5s 75ms/step - loss: 0.6926 - acc: 0.5156 - val_loss: 0.6936 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6920 - acc: 0.5150 - val_loss: 0.6867 - val_acc: 0.4997
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6364 - acc: 0.6399 - val_loss: 0.5163 - val_acc: 0.7490
# Epoch 4/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.3271 - acc: 0.8664 - val_loss: 0.5387 - val_acc: 0.7644
# Epoch 1/20
# 18/18 [==============================] - 4s 75ms/step - loss: 0.6928 - acc: 0.5090 - val_loss: 0.6932 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6912 - acc: 0.5177 - val_loss: 0.6728 - val_acc: 0.5881
# Epoch 3/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6001 - acc: 0.6859 - val_loss: 0.4974 - val_acc: 0.7683
# Epoch 4/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2940 - acc: 0.8860 - val_loss: 0.4858 - val_acc: 0.7996
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 73ms/step - loss: 0.6925 - acc: 0.5162 - val_loss: 0.6938 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6873 - acc: 0.5313 - val_loss: 0.6027 - val_acc: 0.7079
# Epoch 3/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.5542 - acc: 0.7180 - val_loss: 0.5258 - val_acc: 0.7628
# Epoch 4/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.2736 - acc: 0.8893 - val_loss: 0.5866 - val_acc: 0.7781
# Epoch 1/20
# 18/18 [==============================] - 4s 74ms/step - loss: 0.6927 - acc: 0.5131 - val_loss: 0.6941 - val_acc: 0.4992
# Epoch 2/20
# ...
# Epoch 1/20
# 18/18 [==============================] - 4s 94ms/step - loss: 0.6925 - acc: 0.5242 - val_loss: 0.6935 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 35ms/step - loss: 0.6916 - acc: 0.5260 - val_loss: 0.6863 - val_acc: 0.5008
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6303 - acc: 0.6226 - val_loss: 0.5124 - val_acc: 0.7534
# Epoch 4/20
# 18/18 [==============================] - 1s 35ms/step - loss: 0.3435 - acc: 0.8623 - val_loss: 0.4697 - val_acc: 0.7952
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 73ms/step - loss: 0.6930 - acc: 0.5146 - val_loss: 0.6945 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6914 - acc: 0.5174 - val_loss: 0.6787 - val_acc: 0.5014
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6078 - acc: 0.6271 - val_loss: 0.4996 - val_acc: 0.7765
# Epoch 4/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.3222 - acc: 0.8722 - val_loss: 0.4771 - val_acc: 0.7963
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 5s 75ms/step - loss: 0.6931 - acc: 0.5009 - val_loss: 0.6955 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6929 - acc: 0.5163 - val_loss: 0.6914 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6538 - acc: 0.5781 - val_loss: 0.5275 - val_acc: 0.7386
# Epoch 4/20
# 18/18 [==============================] - 1s 35ms/step - loss: 0.3554 - acc: 0.8570 - val_loss: 0.4697 - val_acc: 0.7985
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 74ms/step - loss: 0.6927 - acc: 0.5137 - val_loss: 0.6965 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6886 - acc: 0.5208 - val_loss: 0.6387 - val_acc: 0.6722
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.5318 - acc: 0.7580 - val_loss: 0.5420 - val_acc: 0.7683
# Epoch 4/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2523 - acc: 0.9070 - val_loss: 0.5124 - val_acc: 0.7990
# Epoch 5/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.1266 - acc: 0.9602 - val_loss: 0.8226 - val_acc: 0.7820
# Epoch 1/20
# 18/18 [==============================] - 4s 75ms/step - loss: 0.6927 - acc: 0.5140 - val_loss: 0.6938 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6902 - acc: 0.5262 - val_loss: 0.6642 - val_acc: 0.5189
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.5780 - acc: 0.6888 - val_loss: 0.4933 - val_acc: 0.7831
# Epoch 4/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2595 - acc: 0.8993 - val_loss: 0.5179 - val_acc: 0.7952
# Epoch 1/20
# 18/18 [==============================] - 4s 74ms/step - loss: 0.6933 - acc: 0.5024 - val_loss: 0.6950 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 35ms/step - loss: 0.6928 - acc: 0.5177 - val_loss: 0.6938 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 35ms/step - loss: 0.6775 - acc: 0.5380 - val_loss: 1.0001 - val_acc: 0.6282
# Epoch 1/20
# 18/18 [==============================] - 4s 74ms/step - loss: 0.6927 - acc: 0.5135 - val_loss: 0.6941 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6918 - acc: 0.5122 - val_loss: 0.6834 - val_acc: 0.5014
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6092 - acc: 0.6759 - val_loss: 0.5086 - val_acc: 0.7617
# Epoch 4/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2920 - acc: 0.8833 - val_loss: 0.5024 - val_acc: 0.7930
# Epoch 5/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.1380 - acc: 0.9569 - val_loss: 0.5948 - val_acc: 0.7908
# Epoch 1/20
# 18/18 [==============================] - 5s 76ms/step - loss: 0.6925 - acc: 0.5217 - val_loss: 0.6945 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6911 - acc: 0.5209 - val_loss: 0.6726 - val_acc: 0.6842
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.5900 - acc: 0.7207 - val_loss: 0.5069 - val_acc: 0.7496
# Epoch 4/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.3220 - acc: 0.8801 - val_loss: 0.5729 - val_acc: 0.7880
# Epoch 1/20
# 18/18 [==============================] - 4s 73ms/step - loss: 0.6927 - acc: 0.5248 - val_loss: 0.6941 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6908 - acc: 0.5290 - val_loss: 0.6772 - val_acc: 0.5102
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.5980 - acc: 0.6617 - val_loss: 0.4994 - val_acc: 0.7759
# Epoch 4/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.2665 - acc: 0.8960 - val_loss: 0.5276 - val_acc: 0.7672
# Epoch 1/20
# 18/18 [==============================] - 4s 74ms/step - loss: 0.6934 - acc: 0.5072 - val_loss: 0.6951 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6922 - acc: 0.5245 - val_loss: 0.6929 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6768 - acc: 0.5603 - val_loss: 0.6095 - val_acc: 0.6694
# Epoch 4/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.4450 - acc: 0.7882 - val_loss: 0.4643 - val_acc: 0.8001
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 74ms/step - loss: 0.6929 - acc: 0.5180 - val_loss: 0.6947 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6910 - acc: 0.5237 - val_loss: 0.6830 - val_acc: 0.5184
# Epoch 3/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6289 - acc: 0.6111 - val_loss: 0.5442 - val_acc: 0.7606
# Epoch 4/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.3526 - acc: 0.8763 - val_loss: 0.5517 - val_acc: 0.7919
# Epoch 1/20
# 18/18 [==============================] - 4s 93ms/step - loss: 0.6930 - acc: 0.5051 - val_loss: 0.6936 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6914 - acc: 0.5274 - val_loss: 0.6851 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6323 - acc: 0.6286 - val_loss: 0.5588 - val_acc: 0.7232
# Epoch 4/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.3505 - acc: 0.8609 - val_loss: 0.6050 - val_acc: 0.7820
# Epoch 1/20
# 18/18 [==============================] - 4s 73ms/step - loss: 0.6924 - acc: 0.5158 - val_loss: 0.6932 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 35ms/step - loss: 0.6916 - acc: 0.5195 - val_loss: 0.6808 - val_acc: 0.5036
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6183 - acc: 0.6351 - val_loss: 0.5619 - val_acc: 0.7364
# Epoch 4/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.3211 - acc: 0.8756 - val_loss: 0.4849 - val_acc: 0.7902
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 74ms/step - loss: 0.6926 - acc: 0.5145 - val_loss: 0.6940 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 35ms/step - loss: 0.6894 - acc: 0.5268 - val_loss: 0.6506 - val_acc: 0.5964
# Epoch 3/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.5807 - acc: 0.7290 - val_loss: 0.5246 - val_acc: 0.7759
# Epoch 4/20
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2712 - acc: 0.8950 - val_loss: 0.5578 - val_acc: 0.7990
# Epoch 1/20
# 18/18 [==============================] - 4s 75ms/step - loss: 0.6927 - acc: 0.5239 - val_loss: 0.6933 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6924 - acc: 0.5222 - val_loss: 0.6941 - val_acc: 0.4992
# Epoch 1/20
# 18/18 [==============================] - 4s 74ms/step - loss: 0.6926 - acc: 0.5176 - val_loss: 0.6933 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6922 - acc: 0.5156 - val_loss: 0.6909 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6411 - acc: 0.5955 - val_loss: 0.5500 - val_acc: 0.7414
# Epoch 4/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.3522 - acc: 0.8547 - val_loss: 0.5171 - val_acc: 0.7864
# Epoch 5/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.1550 - acc: 0.9474 - val_loss: 0.5894 - val_acc: 0.7924
# Epoch 1/20
# 18/18 [==============================] - 4s 74ms/step - loss: 0.6928 - acc: 0.5169 - val_loss: 0.7021 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 35ms/step - loss: 0.6933 - acc: 0.5234 - val_loss: 0.6896 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6496 - acc: 0.5763 - val_loss: 0.5224 - val_acc: 0.7633
# Epoch 4/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.3201 - acc: 0.8703 - val_loss: 0.4880 - val_acc: 0.7985
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 75ms/step - loss: 0.6924 - acc: 0.5260 - val_loss: 0.6932 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 35ms/step - loss: 0.6922 - acc: 0.5171 - val_loss: 0.6944 - val_acc: 0.4992
# Epoch 1/20
# 18/18 [==============================] - 5s 75ms/step - loss: 0.6930 - acc: 0.5212 - val_loss: 0.6939 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 35ms/step - loss: 0.6924 - acc: 0.5142 - val_loss: 0.6966 - val_acc: 0.4992
# Epoch 1/20
# 18/18 [==============================] - 4s 74ms/step - loss: 0.6929 - acc: 0.5196 - val_loss: 0.6949 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6920 - acc: 0.5198 - val_loss: 0.6790 - val_acc: 0.5766
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6111 - acc: 0.6444 - val_loss: 0.5204 - val_acc: 0.7694
# Epoch 4/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.2737 - acc: 0.8930 - val_loss: 0.4677 - val_acc: 0.8051
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 73ms/step - loss: 0.6930 - acc: 0.5014 - val_loss: 0.6979 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6905 - acc: 0.5336 - val_loss: 0.6912 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6594 - acc: 0.5869 - val_loss: 0.5062 - val_acc: 0.7617
# Epoch 4/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.2980 - acc: 0.8817 - val_loss: 0.4877 - val_acc: 0.7908
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 5s 74ms/step - loss: 0.6929 - acc: 0.5058 - val_loss: 0.6947 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6918 - acc: 0.5259 - val_loss: 0.6931 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6899 - acc: 0.5319 - val_loss: 0.6547 - val_acc: 0.5711
# Epoch 4/20
# 18/18 [==============================] - 1s 35ms/step - loss: 0.5431 - acc: 0.7382 - val_loss: 0.4885 - val_acc: 0.7891
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 76ms/step - loss: 0.6929 - acc: 0.5159 - val_loss: 0.6937 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6923 - acc: 0.5201 - val_loss: 0.6938 - val_acc: 0.4992
# Epoch 1/20
# 18/18 [==============================] - 4s 71ms/step - loss: 0.6928 - acc: 0.5086 - val_loss: 0.6934 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6914 - acc: 0.5199 - val_loss: 0.6767 - val_acc: 0.5069
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.5977 - acc: 0.6677 - val_loss: 0.4866 - val_acc: 0.7677
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 75ms/step - loss: 0.6930 - acc: 0.5011 - val_loss: 0.6956 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6934 - acc: 0.5107 - val_loss: 0.6915 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6394 - acc: 0.5908 - val_loss: 0.4816 - val_acc: 0.7754
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 74ms/step - loss: 0.6928 - acc: 0.5147 - val_loss: 0.6942 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6897 - acc: 0.5240 - val_loss: 0.7219 - val_acc: 0.5063
# Epoch 1/20
# 18/18 [==============================] - 4s 74ms/step - loss: 0.6929 - acc: 0.5196 - val_loss: 0.6944 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6911 - acc: 0.5293 - val_loss: 0.6873 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6304 - acc: 0.6105 - val_loss: 0.5083 - val_acc: 0.7490
# Epoch 4/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.3071 - acc: 0.8789 - val_loss: 0.5084 - val_acc: 0.7974
# Epoch 1/20
# 18/18 [==============================] - 4s 73ms/step - loss: 0.6927 - acc: 0.5130 - val_loss: 0.6949 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6919 - acc: 0.5219 - val_loss: 0.6881 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6452 - acc: 0.6133 - val_loss: 0.5517 - val_acc: 0.7353
# Epoch 4/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.3728 - acc: 0.8534 - val_loss: 0.4862 - val_acc: 0.8094
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 75ms/step - loss: 0.6926 - acc: 0.5122 - val_loss: 0.6934 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6922 - acc: 0.5211 - val_loss: 0.6942 - val_acc: 0.4992
# Epoch 1/20
# 18/18 [==============================] - 4s 73ms/step - loss: 0.6926 - acc: 0.5253 - val_loss: 0.6931 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6912 - acc: 0.5201 - val_loss: 0.6718 - val_acc: 0.5651
# Epoch 3/20
# 18/18 [==============================] - 1s 35ms/step - loss: 0.5919 - acc: 0.6748 - val_loss: 0.4688 - val_acc: 0.7814
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 76ms/step - loss: 0.6929 - acc: 0.5087 - val_loss: 0.6942 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.6917 - acc: 0.5193 - val_loss: 0.6904 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6305 - acc: 0.6089 - val_loss: 0.5339 - val_acc: 0.7578
# Epoch 4/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.3295 - acc: 0.8635 - val_loss: 0.4868 - val_acc: 0.8018
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 94ms/step - loss: 0.6925 - acc: 0.5244 - val_loss: 0.6932 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6924 - acc: 0.5186 - val_loss: 0.6925 - val_acc: 0.4992
# Epoch 3/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6619 - acc: 0.5777 - val_loss: 0.5695 - val_acc: 0.7216
# Epoch 4/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.3498 - acc: 0.8545 - val_loss: 0.4722 - val_acc: 0.7963
#
# Reached 0.49 loss!
# Epoch 1/20
# 18/18 [==============================] - 4s 74ms/step - loss: 0.6926 - acc: 0.5233 - val_loss: 0.6934 - val_acc: 0.4992
# Epoch 2/20
# 18/18 [==============================] - 1s 34ms/step - loss: 0.6893 - acc: 0.5207 - val_loss: 0.6396 - val_acc: 0.6463
# Epoch 3/20
# 18/18 [==============================] - 1s 33ms/step - loss: 0.5555 - acc: 0.7362 - val_loss: 0.5278 - val_acc: 0.7688
# Epoch 4/20
# 18/18 [==============================] - 1s 35ms/step - loss: 0.2532 - acc: 0.9046 - val_loss: 0.4816 - val_acc: 0.8078
#
# Reached 0.49 loss!

# %%
# del model
model = get_cnn_rand(max_len)
model.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_dynamic (InputLayer)      [(None, 49)]         0
# __________________________________________________________________________________________________
# embeddings_layer_dynamic (Embed (None, 49, 50)       691800      input_dynamic[0][0]
# __________________________________________________________________________________________________
# Conv_dynamic_3 (Conv1D)         (None, 47, 100)      15100       embeddings_layer_dynamic[0][0]
# __________________________________________________________________________________________________
# Conv_dynamic_4 (Conv1D)         (None, 46, 100)      20100       embeddings_layer_dynamic[0][0]
# __________________________________________________________________________________________________
# Conv_dynamic_5 (Conv1D)         (None, 45, 100)      25100       embeddings_layer_dynamic[0][0]
# __________________________________________________________________________________________________
# MaxPooling_dynamic_3 (MaxPoolin (None, 23, 100)      0           Conv_dynamic_3[0][0]
# __________________________________________________________________________________________________
# MaxPooling_dynamic_4 (MaxPoolin (None, 23, 100)      0           Conv_dynamic_4[0][0]
# __________________________________________________________________________________________________
# MaxPooling_dynamic_5 (MaxPoolin (None, 22, 100)      0           Conv_dynamic_5[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 68, 100)      0           MaxPooling_dynamic_3[0][0]
#                                                                  MaxPooling_dynamic_4[0][0]
#                                                                  MaxPooling_dynamic_5[0][0]
# __________________________________________________________________________________________________
# lstm_17 (LSTM)                  (None, 68, 64)       42240       concatenate_17[0][0]
# __________________________________________________________________________________________________
# lstm_18 (LSTM)                  (None, 64)           33024       lstm_17[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 64)           0           lstm_18[0][0]
# __________________________________________________________________________________________________
# FC1 (Dense)                     (None, 20)           1300        dropout_14[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 20)           0           FC1[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            21          dropout_15[0][0]
# ==================================================================================================
# Total params: 828,685
# Trainable params: 828,685
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model.fit(
            x=train_x,
            y=train_y,
            batch_size=50,
            epochs=20,
            validation_data=(test_x, test_y),
            # callbacks=[earlystop],
        )
# Out:
# Epoch 1/20
# 139/139 [==============================] - 6s 22ms/step - loss: 0.6858 - acc: 0.5252 - val_loss: 0.5188 - val_acc: 0.7611
# Epoch 2/20
# 139/139 [==============================] - 2s 17ms/step - loss: 0.3619 - acc: 0.8574 - val_loss: 0.4397 - val_acc: 0.8105
# Epoch 3/20
# 139/139 [==============================] - 2s 17ms/step - loss: 0.1378 - acc: 0.9536 - val_loss: 0.5776 - val_acc: 0.7985
# Epoch 4/20
# 139/139 [==============================] - 2s 16ms/step - loss: 0.0677 - acc: 0.9787 - val_loss: 0.8087 - val_acc: 0.8062
# Epoch 5/20
#  73/139 [==============>...............] - ETA: 0s - loss: 0.0234 - acc: 0.9956
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-54-ee3303c67b4b> in <module>()
#       4             batch_size=50,
#       5             epochs=20,
# ----> 6             validation_data=(test_x, test_y),
#       7             # callbacks=[earlystop],
#       8         )
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
from tensorflow.keras.models import load_model

# 保存模型
# model.save("10in_32unit_temp_res.h5")
# del model  # deletes the existing model
# 导入已经训练好的模型
# model = load_model("my_model.h5")
## 保存训练好的Tokenizer，和导入
import pickle

# saving
with open("/content/drive/MyDrive/Sentiment Analysis/tokenizer/49in_SST.pickle", "wb") as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
loss, accuracy = model.evaluate(x=[test_x, test_x], y=test_y, verbose=0)
print(loss)
print(accuracy)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-986df98acfc1> in <module>()
# ----> 1 loss, accuracy = model.evaluate(x=[test_x, test_x], y=test_y, verbose=0)
#       2 print(loss)
#       3 print(accuracy)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1387             with trace.Trace('test', step_num=step, _r=1):
#    1388               callbacks.on_test_batch_begin(step)
# -> 1389               tmp_logs = self.test_function(iterator)
#    1390               if data_handler.should_sync:
#    1391                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     860       # In this case we have not created variables on the first call. So we can
#     861       # run the first trace but we should fail if variables are created.
# --> 862       results = self._stateful_fn(*args, **kwds)
#     863       if self._created_variables:
#     864         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2939     with self._lock:
#    2940       (graph_function,
# -> 2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3356               call_context_key in self._function_cache.missed):
#    3357             return self._define_function_with_shape_relaxation(
# -> 3358                 args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3359
#    3360           self._function_cache.missed.add(call_context_key)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _define_function_with_shape_relaxation(self, args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3278
#    3279     graph_function = self._create_graph_function(
# -> 3280         args, kwargs, override_flat_arg_shapes=relaxed_arg_shapes)
#    3281     self._function_cache.arg_relaxed[rank_only_cache_key] = graph_function
#    3282
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3204             arg_names=arg_names,
#    3205             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3206             capture_by_value=self._capture_by_value),
#    3207         self._function_attributes,
#    3208         function_spec=self.function_spec,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     988         _, original_func = tf_decorator.unwrap(python_func)
#     989
# --> 990       func_outputs = python_func(*func_args, **func_kwargs)
#     991
#     992       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     632             xla_context.Exit()
#     633         else:
# --> 634           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     635         return out
#     636
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     975           except Exception as e:  # pylint:disable=broad-except
#     976             if hasattr(e, "ag_error_metadata"):
# --> 977               raise e.ag_error_metadata.to_exception(e)
#     978             else:
#     979               raise
#
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1233 test_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1224 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:1259 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:2730 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:3417 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1217 run_step  **
#         outputs = model.test_step(data)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1183 test_step
#         y_pred = self(x, training=False)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/base_layer.py:998 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/input_spec.py:207 assert_input_compatibility
#         ' input tensors. Inputs received: ' + str(inputs))
#
#     ValueError: Layer model_15 expects 1 input(s), but it received 2 input tensors. Inputs received: [<tf.Tensor 'IteratorGetNext:0' shape=(None, 49) dtype=int32>, <tf.Tensor 'IteratorGetNext:1' shape=(None, 49) dtype=int32>]

# %% [markdown]
# ### google

# %%
def load_google():
    Word2VecModel = gensim.models.KeyedVectors.load_word2vec_format(
        r"E:\CS\MLT\GoogleNews-vectors-negative300.bin", binary=True
    )

    vocab_list = [word for word, Vocab in Word2VecModel.wv.vocab.items()]  # 存储 所有的 词语

    # word_index = {" ": 0}  # 初始化 `[word : token]` ，后期 tokenize 语料库就是用该词典。
    embeddings_index = {}  # 初始化`[word : vector]`字典

    for i in range(len(vocab_list)):
        # print(i)
        word = vocab_list[i]  # 每个词语
        # word_index[word] = i + 1 # 词语：序号
        embeddings_index[word] = Word2VecModel.wv[word]  # 词语：词向量
        # embeddings_matrix[i + 1] = Word2VecModel.wv[word]  # 词向量矩阵
    return embeddings_index


def load_fasttext_embeddings():
    glove_dir = r"E:\CS\MLT\glove.6B"
    embeddings_index = {}
    f = open(os.path.join(glove_dir, "glove.6B.50d.txt"), encoding="utf-8")
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype="float32")
        embeddings_index[word] = coefs
    f.close()
    print("Found %s word vectors." % len(embeddings_index))
    return embeddings_index


def create_embeddings_matrix(embeddings_index, vocabulary, embedding_dim=100):
    embeddings_matrix = np.random.rand(len(vocabulary) + 1, embedding_dim)
    for i, word in enumerate(vocabulary):
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            embeddings_matrix[i] = embedding_vector
    print("Matrix shape: {}".format(embeddings_matrix.shape))
    return embeddings_matrix


embeddings_index = load_google()
embeddings_matrix = create_embeddings_matrix(embeddings_index, word_index, 300)

# %%
import gensim

Word2VecModel = gensim.models.KeyedVectors.load_word2vec_format(
    r"E:\CS\MLT\GoogleNews-vectors-negative300.bin", binary=True
)

vocab_list = [word for word, Vocab in Word2VecModel.wv.vocab.items()]  # 存储 所有的 词语

word_index = {" ": 0}  # 初始化 `[word : token]` ，后期 tokenize 语料库就是用该词典。
word_vector = {}  # 初始化`[word : vector]`字典

for i in range(len(vocab_list)):
    # print(i)
    word = vocab_list[i]  # 每个词语
    #     word_index[word] = i + 1 # 词语：序号
    #     word_vector[word] = Word2VecModel.wv[word] # 词语：词向量
    embeddings_matrix[i + 1] = Word2VecModel.wv[word]  # 词向量矩阵
